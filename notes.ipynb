# %% [markdown]
# ### - LLM classifies and gives recommendation
# - Phish
# - not phish
# - >
#
#
#
# explain what actions should be taken to trust v not
#
# Common phishing types
#
# - classify phsih v no phish
# - classify phish type
# - safety metric recommendation
#     - dangerous content
#     - harrassement
